# %%
file1 = open('input.txt', 'r')
Lines = file1.readlines()
Lines[:6]
# Out:
# ['2159\n', '2527\n', '2441\n', '3299\n', '1672\n', '3025\n']

# %%
# Using readlines()
file1 = open('format_in.txt', 'r')
Lines = file1.readlines()
len(Lines)
# Out:
# 251

# %%
elf=[int(i) for i in Lines[0].strip('\n').split(",")]
display(elf)
print(sum(elf))
print(max(elf))
# Out:
# [2159, 2527, 2441, 3299, 1672, 3025, 2820, 6821, 3201, 1204, 1208, 4861, 5621]
# 40859
# 6821

# %%
elves=[ [int(i) for i in j.strip('\n').split(",")] for j in Lines ]

# %%
elves_sum=[ sum(j) for j in elves ]

# %%
(max(elves_sum),elves_sum.index(max(elves_sum))+1)
# Out:
# (69289, 53)

# %%
max([ sum([int(i) for i in j.strip('\n').split(",")]) for j in open('format_in.txt', 'r').readlines() ])
# Out:
# 69289

# %%
sum(sorted([ sum([int(i) for i in j.strip('\n').split(",")]) for j in open('format_in.txt', 'r').readlines() ],reverse=True)[:3])
# Out:
# 205615

# %%
#open text file in read mode
text_file = open("input_orig.txt", "r")
#read whole file to a string
data = text_file.read()
#close file
text_file.close()
elf_strings=[data.split("\n\n")] 
elves=[i.split('\n') for i in data.split('\n\n')]

# %%
elf_strings
# Out:
# [['2159\n2527\n2441\n3299\n1672\n3025\n2820\n6821\n3201\n1204\n1208\n4861\n5621',
#   '5580\n18071',
#   '8803\n1667\n4173\n9404\n9718\n10311',
#   '12237\n5068\n9824\n6535',
#   '25484',
#   '18598\n2851\n13577',
#   '13719\n9147\n11204\n8554\n11796\n1297',
#   '43055',
#   '8156\n4616',
#   '16383\n17036\n16017\n18569',
#   '33581\n10017',
#   '65566',
#   '5750\n6961\n4494\n11117\n3392\n10471\n3490',
#   '7006\n7526\n9302\n1454\n4039\n8067\n9321\n8888\n7380',
#   '8543\n2106\n2986\n3465\n9592\n11240\n1795',
#   '4396\n27967',
#   '8091\n19515\n1282',
#   '6241\n8946\n6665\n5163\n2224\n8684\n6631\n5866',
#   '5565\n6118\n1856\n3227\n4501\n3024\n5745\n3988\n1590\n5111\n4457\n3108\n3165\n3508\n4629',
#   '1455\n4809\n5650\n5472\n4673\n1775\n3080\n5282\n3552\n3875\n4691\n7352',
#   '7325\n2121\n2751\n10300\n1939\n3782\n3635\n1801',
#   '8562\n15236\n18996\n18271',
#   '9673\n9270\n15540\n5842\n10343',
#   '7384\n30187',
#   '7578\n7909\n8514\n5775\n3455',
#   '2617\n30132',
# ...

# %%
for count,i in enumerate(elves[:]):
    print(i)
    print([int(j) for j in i])
    print(count)
# Out:
# ['2159', '2527', '2441', '3299', '1672', '3025', '2820', '6821', '3201', '1204', '1208', '4861', '5621']
# [2159, 2527, 2441, 3299, 1672, 3025, 2820, 6821, 3201, 1204, 1208, 4861, 5621]
# 0
# ['5580', '18071']
# [5580, 18071]
# 1
# ['8803', '1667', '4173', '9404', '9718', '10311']
# [8803, 1667, 4173, 9404, 9718, 10311]
# 2
# ['12237', '5068', '9824', '6535']
# [12237, 5068, 9824, 6535]
# 3
# ['25484']
# [25484]
# 4
# ['18598', '2851', '13577']
# [18598, 2851, 13577]
# 5
# ['13719', '9147', '11204', '8554', '11796', '1297']
# [13719, 9147, 11204, 8554, 11796, 1297]
# 6
# ['43055']
# [43055]
# 7
# ['8156', '4616']
# [8156, 4616]
# 8
# ['16383', '17036', '16017', '18569']
# [16383, 17036, 16017, 18569]
# 9
# ['33581', '10017']
# [33581, 10017]
# 10
# ['65566']
# [65566]
# 11
# ['5750', '6961', '4494', '11117', '3392', '10471', '3490']
# [5750, 6961, 4494, 11117, 3392, 10471, 3490]
# 12
# ['7006', '7526', '9302', '1454', '4039', '8067', '9321', '8888', '7380']
# ...

# %%
elves_ints = [ [int(i) for i in j] for j in elves]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_20125/4093087432.py in <module>
# ----> 1 elves_ints = [ [int(i) for i in j] for j in elves]
#
# /tmp/ipykernel_20125/4093087432.py in <listcomp>(.0)
# ----> 1 elves_ints = [ [int(i) for i in j] for j in elves]
#
# /tmp/ipykernel_20125/4093087432.py in <listcomp>(.0)
# ----> 1 elves_ints = [ [int(i) for i in j] for j in elves]
#
# ValueError: invalid literal for int() with base 10: ''

# %%
elves=[ int(j) for j in [i.split('\n') for i in data.split('\n\n')] ]
#elves_sum = [sum(int(i.split('\n'))) for i in data.split('\n\n') ]
#elves_max = max([sum(int(i.split('\n'))) for i in data.split('\n\n') ])
elves
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20125/1534535288.py in <module>
# ----> 1 elves=[ int(j) for j in [i.split('\n') for i in data.split('\n\n')] ]
#       2 #elves_sum = [sum(int(i.split('\n'))) for i in data.split('\n\n') ]
#       3 #elves_max = max([sum(int(i.split('\n'))) for i in data.split('\n\n') ])
#       4 elves
#
# /tmp/ipykernel_20125/1534535288.py in <listcomp>(.0)
# ----> 1 elves=[ int(j) for j in [i.split('\n') for i in data.split('\n\n')] ]
#       2 #elves_sum = [sum(int(i.split('\n'))) for i in data.split('\n\n') ]
#       3 #elves_max = max([sum(int(i.split('\n'))) for i in data.split('\n\n') ])
#       4 elves
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
max_elf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20125/2203085608.py in <module>
# ----> 1 max_elf
#
# NameError: name 'max_elf' is not defined
